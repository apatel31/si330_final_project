# %% [markdown]
# # Import Libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Import and Process Data

# %% [markdown]
# First, we bring in data from the world happiness report. There is an individual CSV file for the years 2015 to 2019, as the report has evolved over the years, each dataset has minor fluctuations in formating and variable names. Due to this, we need to standardize all of the datasets and concatenate them into one.

# %%
#Import CSV files
world_hap_2015 = pd.read_csv('data/2015.csv')
world_hap_2016 = pd.read_csv('data/2016.csv')
world_hap_2017 = pd.read_csv('data/2017.csv')
world_hap_2018 = pd.read_csv('data/2018.csv')
world_hap_2019 = pd.read_csv('data/2019.csv')

#Split out country and region, we will later merge this with the original data to make sure there is a 'region' column
#We need to do this because not all datasets have the 'region' column and we will drop it for concatenating before bringing it back in
country_and_region = world_hap_2015[['Country', 'Region']]


#Drop inconsistent/unnecessary columns
world_hap_2015.drop(columns=['Region', 'Happiness Rank', 'Standard Error'], inplace=True)
world_hap_2016.drop(columns=['Region', 'Happiness Rank', 'Lower Confidence Interval', 'Upper Confidence Interval'], inplace=True)
world_hap_2017.drop(columns=['Happiness.Rank', 'Whisker.high', 'Whisker.low'], inplace=True)
world_hap_2018.drop(columns=['Overall rank'], inplace=True)
world_hap_2019.drop(columns=['Overall rank'], inplace=True)


#Give each Dataframe consistent columns
world_hap_2015.columns = ['Country', 'Happiness_Score', 'GDP_per_Capita', 'Social_Support', 'Life_Expectancy', 'Freedom', 'Corruption', 'Generosity', 'Dystopia_Residual']
world_hap_2016.columns = ['Country', 'Happiness_Score', 'GDP_per_Capita', 'Social_Support', 'Life_Expectancy', 'Freedom', 'Corruption', 'Generosity', 'Dystopia_Residual']
world_hap_2017.columns = ['Country', 'Happiness_Score', 'GDP_per_Capita', 'Social_Support', 'Life_Expectancy', 'Freedom','Generosity', 'Corruption', 'Dystopia_Residual']
world_hap_2018.columns = ['Country', 'Happiness_Score', 'GDP_per_Capita', 'Social_Support', 'Life_Expectancy', 'Freedom', 'Generosity', 'Corruption']
world_hap_2019.columns = ['Country', 'Happiness_Score', 'GDP_per_Capita', 'Social_Support', 'Life_Expectancy', 'Freedom', 'Generosity', 'Corruption']

world_hap_2018['Dystopia_Residual'] = world_hap_2018['Happiness_Score'] - (world_hap_2018['GDP_per_Capita']+world_hap_2018['Social_Support']+world_hap_2018['Life_Expectancy']+world_hap_2018['Freedom']+world_hap_2018['Generosity']+world_hap_2018['Corruption'])
world_hap_2019['Dystopia_Residual'] = world_hap_2019['Happiness_Score'] - (world_hap_2019['GDP_per_Capita']+world_hap_2019['Social_Support']+world_hap_2019['Life_Expectancy']+world_hap_2019['Freedom']+world_hap_2019['Generosity']+world_hap_2019['Corruption'])

#Use year to identify where the data is coming from
world_hap_2015['year'] = pd.to_datetime('2015', format='%Y')
world_hap_2016['year'] = pd.to_datetime('2016', format='%Y')
world_hap_2017['year'] = pd.to_datetime('2017', format='%Y')
world_hap_2018['year'] = pd.to_datetime('2018', format='%Y')
world_hap_2019['year'] = pd.to_datetime('2019', format='%Y')

#Concatenate and merge for final dataframe
world_hap = pd.concat([world_hap_2015, world_hap_2016, world_hap_2017, world_hap_2018, world_hap_2019], sort=False)
world_hap = world_hap.merge(country_and_region, how='inner', on='Country')

# %%
gdp_contribution = pd.read_csv('data/GDP_Contribution.csv')

# %%
world_hap = world_hap.merge(gdp_contribution, how='inner', on='Country')

# %%
world_hap.head()
# Out:
#        Country  Happiness_Score  GDP_per_Capita  Social_Support  \
# 0  Switzerland            7.587         1.39651        1.349510
# 1  Switzerland            7.509         1.52733        1.145240
# 2  Switzerland            7.494         1.56498        1.516912
# 3  Switzerland            7.487         1.42000        1.549000
# 4  Switzerland            7.480         1.45200        1.526000
#
#    Life_Expectancy   Freedom  Corruption  Generosity  Dystopia_Residual  \
# 0         0.941430  0.665570    0.419780    0.296780           2.517380
# 1         0.863030  0.585570    0.412030    0.280830           2.694630
# 2         0.858131  0.620071    0.367007    0.290549           2.276716
# 3         0.927000  0.660000    0.357000    0.256000           2.318000
# 4         1.052000  0.572000    0.343000    0.263000           2.272000
#
#         year          Region  Year    GDP  Agriculture  Industry  \
# 0 2015-01-01  Western Europe  2019  703.1          1.0      26.0
# ...

# %% [markdown]
# # Data Exploration

# %% [markdown]
# ## Average Happiness by Region

# %%
def heatmap_formating():
    # The following code was found on github forums posted by user SalMac86 to modify the sizing of the heatmap
    # fix for mpl bug that cuts off top/bottom of seaborn viz
    b, t = plt.ylim() # discover the values for bottom and top
    b += 0.5 # Add 0.5 to the bottom
    t -= 0.5 # Subtract 0.5 from the top
    plt.ylim(b, t) # update the ylim(bottom, top) values
    plt.show() # ta-da!


def single_col_heatmap(df, y_axis, x_axis):

    df = df.groupby(y_axis).agg({x_axis: np.nanmean}).sort_values(by=x_axis, ascending=False)

    # plot a heatmap with annotation
    plt.figure(figsize = (8,10))
    sns.heatmap(df, annot=True, annot_kws={"size": 12}, linewidths=2, cmap="YlGnBu")
    heatmap_formating()



single_col_heatmap(world_hap, 'Region', 'Happiness_Score')

# %%
def single_barchart(df, y_axis, x_axis):
    sns.set(style="darkgrid")

    # Set the figure size
    plt.figure(figsize=(30, 10))

    df = df.sort_values([y_axis], ascending=False).reset_index(drop=True)

    # plot a bar chart
    sns.barplot(
        x=x_axis, 
        y=y_axis, 
        data=df, 
        estimator=np.median, 
        ci=None, 
        color='#69b3a2')
    
single_barchart(world_hap, 'Happiness_Score', 'Region')

# %% [markdown]
# From the above table, we find that Australia, New Zealand, North America, and Western Europe are the most happy regions.

# %% [markdown]
# ## Largest Contributor to Happiness by Region

# %%
world_hap['GDP_per_Capita'] = world_hap['GDP_per_Capita'] / world_hap['Happiness_Score']
world_hap['Freedom'] = world_hap['Freedom'] / world_hap['Happiness_Score']
world_hap['Generosity'] = world_hap['Generosity'] / world_hap['Happiness_Score']
world_hap['Life_Expectancy'] = world_hap['Life_Expectancy'] / world_hap['Happiness_Score']
world_hap['Social_Support'] = world_hap['Social_Support'] / world_hap['Happiness_Score']
world_hap['Corruption'] = world_hap['Corruption'] / world_hap['Happiness_Score']

# %%
def multi_col_heatmap(df, y_axis, label_list, aggregation):
    
    labels = {}
    for label in label_list:
        labels[label] = aggregation
        
    df = df.groupby(y_axis).agg(labels)
    
    # plot a heatmap with annotation
    plt.figure(figsize = (16,10))
    sns.heatmap(df, annot=True, annot_kws={"size": 12}, linewidths=2, cmap="YlGnBu")
    heatmap_formating()
    
multi_col_heatmap(world_hap, 'Region', ['GDP_per_Capita', 'Freedom', 'Generosity', 'Life_Expectancy', 'Social_Support', 'Corruption'], np.nanmean)

# %% [markdown]
# ## Data Analysis

# %% [markdown]
# We want to find the industries that contribute the most to happiness in various countries and regions. From there, our goal is to identify any glaring trends in the relationship between GDP, industries, and happiness.

# %%
gdp_analysis = world_hap[['Country', 'Happiness_Score', 'year', 'Region', 'GDP', 'Agriculture', 'Industry', 'Manufacturing', 'Services']]

# %%
gdp_analysis.head()
# Out:
#        Country  Happiness_Score       year          Region    GDP  \
# 0  Switzerland            7.587 2015-01-01  Western Europe  703.1
# 1  Switzerland            7.509 2016-01-01  Western Europe  703.1
# 2  Switzerland            7.494 2017-01-01  Western Europe  703.1
# 3  Switzerland            7.487 2018-01-01  Western Europe  703.1
# 4  Switzerland            7.480 2019-01-01  Western Europe  703.1
#
#    Agriculture  Industry  Manufacturing  Services
# 0          1.0      26.0           19.0      70.9
# 1          1.0      26.0           19.0      70.9
# 2          1.0      26.0           19.0      70.9
# 3          1.0      26.0           19.0      70.9
# 4          1.0      26.0           19.0      70.9

# %%
multi_col_heatmap(gdp_analysis, 'Region', ['Agriculture', 'Industry', 'Manufacturing', 'Services'], np.nanmean)

# %% [markdown]
# ### Plotting Linear relationship between industry emphasis and happiness

# %%
def plot_simple_reg(df, x, y):
    plt.figure(figsize = (16,10))
    sns.regplot(x=df[x], y=df[y])

    
plot_simple_reg(gdp_analysis, 'Services', 'Happiness_Score')
plot_simple_reg(gdp_analysis, 'Agriculture', 'Happiness_Score')
plot_simple_reg(gdp_analysis, 'Industry', 'Happiness_Score')
plot_simple_reg(gdp_analysis, 'Manufacturing', 'Happiness_Score')

# %% [markdown]
# ## Statistical Tests

# %%
def get_r2(df, x, y):
    return df[x].corr(df[y])

print('Correlation Coefficient between Happiness and Services')
print(get_r2(gdp_analysis, 'Services', 'Happiness_Score'))

print('Correlation Coefficient between Happiness and Agriculture')
print(get_r2(gdp_analysis, 'Agriculture', 'Happiness_Score'))

print('Correlation Coefficient between Happiness and Industry')
print(get_r2(gdp_analysis, 'Industry', 'Happiness_Score'))

print('Correlation Coefficient between Happiness and Manufacturing')
print(get_r2(gdp_analysis, 'Manufacturing', 'Happiness_Score'))
# Out:
# Correlation Coefficient between Happiness and Services
# 0.5851318868907975
# Correlation Coefficient between Happiness and Agriculture
# -0.6605589877120482
# Correlation Coefficient between Happiness and Industry
# 0.12457058332998351
# Correlation Coefficient between Happiness and Manufacturing
# 0.14262014947194723

# %% [markdown]
# ## Testing

# %% [markdown]
# The following are the main functions we made for this project:
# - single_barchart
# - multi_col_heatmap
# - plot_simple_reg
# - get_r2

# %% [markdown]
# To test for these, we created a dummy dataframe with random data and passed in a variety of parameters in each one to see if they worked like we expect them too. Since the majority of these functions are for visualizations, we primarily eyeballed the results to see if they were what we expected.

# %%
import random


test_categories = ['blue', 'red', 'green']

def random_category(x):
    return random.choice(test_categories)

test_data = pd.DataFrame(np.random.randint(0,100,size=(100, 4)), columns=list('ABCD'))

test_data['category'] = 'temp'
test_data['category'] = test_data['category'].apply(random_category)
test_data.head()
# Out:
#     A   B   C   D category
# 0  51  38  94  67    green
# 1   3  50  89  61    green
# 2  99  48  44  25      red
# 3  52  38  39  68    green
# 4  71  38  73  18     blue

# %% [markdown]
# ### Testing single_barchart

# %% [markdown]
# Parameters:
#    - df: dataframe object
#    - x_axis: string object
#    - y_axis: string object

# %%
single_barchart(test_data, 'A', 'category')
single_barchart(test_data, 'B', 'C')
single_barchart(test_data, 'D', 'category')

# %% [markdown]
# ### Testing multi_col_heatmap

# %% [markdown]
# Parameters:
#    - df: dataframe object
#    - y_axis: string object
#    - label_list: list object
#    - aggregation: type of aggregation (mean, sum, etc)

# %%
multi_col_heatmap(test_data, 'category', ['A', 'B', 'C'], sum)
multi_col_heatmap(test_data, 'A', ['B', 'C'], np.nanmean)
multi_col_heatmap(test_data, 'category', ['A', 'C'], sum)
multi_col_heatmap(test_data, 'D', ['A', 'B', 'C'], sum)

# %% [markdown]
# ### Testing plot_simple_reg

# %% [markdown]
# Parameters:
#    - df: dataframe object
#    - x: string object
#    - y: string object

# %%
plot_simple_reg(test_data, 'A', 'D')
plot_simple_reg(test_data, 'A', 'B')
plot_simple_reg(test_data, 'B', 'C')

# %% [markdown]
# ### Testing get_r2

# %% [markdown]
# Parameters:
#    - df: dataframe object
#    - x: string object
#    - y: string object

# %%
print(get_r2(test_data, 'A', 'D'))
print(get_r2(test_data, 'A', 'B'))
print(get_r2(test_data, 'B', 'C'))
# Out:
# 0.10229409922164438
# 0.08843603889505659
# 0.2354543918822216
